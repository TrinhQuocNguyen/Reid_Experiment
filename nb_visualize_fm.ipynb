# %%
import torch
import torch.nn as nn
import torchvision
from torchvision import models, transforms, utils
from torch.autograd import Variable
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc
from PIL import Image
import json
# %matplotlib inline

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=0., std=1.)
])

# %%
print(torch.__version__)
# Out:
# 1.12.1

# %%
image = Image.open(str('dog.png'))
plt.imshow(image)

# %%
model = models.resnet101(pretrained=True)
print(model)
# Out:
# /home/dl-box/anaconda3/envs/trinh-quickdemo/lib/python3.7/site-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /home/dl-box/anaconda3/envs/trinh-quickdemo/lib/python3.7/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /home/dl-box/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
# 100.0%
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
# we will save the conv layer weights in this list
model_weights =[]
#we will save the 49 conv layers in this list
conv_layers = []
# get all the model children as list
model_children = list(model.children())
#counter to keep count of the conv layers
counter = 0
#append all the conv layers and their respective wights to the list
for i in range(len(model_children)):
    if type(model_children[i]) == nn.Conv2d:
        counter+=1
        model_weights.append(model_children[i].weight)
        conv_layers.append(model_children[i])
    elif type(model_children[i]) == nn.Sequential:
        for j in range(len(model_children[i])):
            for child in model_children[i][j].children():
                if type(child) == nn.Conv2d:
                    counter+=1
                    model_weights.append(child.weight)
                    conv_layers.append(child)
print(f"Total convolution layers: {counter}")
counter = 0
for i in conv_layers:
    print("Layer "+ str(counter) + " :", i)
    counter+=1
# Out:
# Total convolution layers: 100
# Layer 0 : Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# Layer 1 : Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 2 : Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 3 : Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 4 : Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 5 : Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 6 : Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 7 : Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 8 : Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 9 : Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 10 : Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 11 : Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# Layer 12 : Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 13 : Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 14 : Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 15 : Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 16 : Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 17 : Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 18 : Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 19 : Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 20 : Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 21 : Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 22 : Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 23 : Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# Layer 24 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 25 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 26 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 27 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 28 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 29 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 30 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 31 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 32 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 33 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 34 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 35 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 36 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 37 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 38 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 39 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 40 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 41 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 42 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 43 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 44 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 45 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 46 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 47 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 48 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 49 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 50 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 51 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 52 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 53 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 54 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 55 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 56 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 57 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 58 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 59 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 60 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 61 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 62 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 63 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 64 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 65 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 66 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 67 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 68 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 69 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 70 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 71 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 72 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 73 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 74 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 75 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 76 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 77 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 78 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 79 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 80 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 81 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 82 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 83 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 84 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 85 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 86 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 87 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 88 : Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 89 : Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 90 : Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 91 : Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 92 : Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# Layer 93 : Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 94 : Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 95 : Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 96 : Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 97 : Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Layer 98 : Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Layer 99 : Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# %%
image = transform(image)
print(f"Image shape before: {image.shape}")
image = image.unsqueeze(0)
print(f"Image shape after: {image.shape}")
image = image.to(device)
# Out:
# Image shape before: torch.Size([3, 224, 224])
# Image shape after: torch.Size([1, 3, 224, 224])

# %%
outputs = []
names = []
for layer in conv_layers[0:]:
    image = layer(image)
    outputs.append(image)
    names.append(str(layer))
print(len(outputs))
#print feature_maps
for feature_map in outputs:
    print(feature_map.shape)
# Out:
# 100
# torch.Size([1, 64, 112, 112])
# torch.Size([1, 64, 112, 112])
# torch.Size([1, 64, 112, 112])
# torch.Size([1, 256, 112, 112])
# torch.Size([1, 64, 112, 112])
# torch.Size([1, 64, 112, 112])
# torch.Size([1, 256, 112, 112])
# torch.Size([1, 64, 112, 112])
# torch.Size([1, 64, 112, 112])
# torch.Size([1, 256, 112, 112])
# torch.Size([1, 128, 112, 112])
# torch.Size([1, 128, 56, 56])
# torch.Size([1, 512, 56, 56])
# torch.Size([1, 128, 56, 56])
# torch.Size([1, 128, 56, 56])
# torch.Size([1, 512, 56, 56])
# torch.Size([1, 128, 56, 56])
# torch.Size([1, 128, 56, 56])
# torch.Size([1, 512, 56, 56])
# torch.Size([1, 128, 56, 56])
# torch.Size([1, 128, 56, 56])
# torch.Size([1, 512, 56, 56])
# torch.Size([1, 256, 56, 56])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 256, 28, 28])
# torch.Size([1, 1024, 28, 28])
# torch.Size([1, 512, 28, 28])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 2048, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 2048, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 512, 14, 14])
# torch.Size([1, 2048, 14, 14])

# %%
processed = []
for feature_map in outputs:
    feature_map = feature_map.squeeze(0)
    gray_scale = torch.sum(feature_map,0)
    gray_scale = gray_scale / feature_map.shape[0]
    processed.append(gray_scale.data.cpu().numpy())
for fm in processed:
    print(fm.shape)
# Out:
# (112, 112)
# (112, 112)
# (112, 112)
# (112, 112)
# (112, 112)
# (112, 112)
# (112, 112)
# (112, 112)
# (112, 112)
# (112, 112)
# (112, 112)
# (56, 56)
# (56, 56)
# (56, 56)
# (56, 56)
# (56, 56)
# (56, 56)
# (56, 56)
# (56, 56)
# (56, 56)
# (56, 56)
# (56, 56)
# (56, 56)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (28, 28)
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)
# (14, 14)

# %%
fig = plt.figure(figsize=(30, 50))
for i in range(len(processed)):
    a = fig.add_subplot(10, 10, i+1)
    imgplot = plt.imshow(processed[i])
    a.axis("off")
    a.set_title(names[i].split('(')[0] + "-"+ str(i), fontsize=20)
plt.savefig(str('feature_maps.jpg'), bbox_inches='tight')
